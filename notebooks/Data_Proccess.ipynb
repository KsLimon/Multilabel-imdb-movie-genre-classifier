# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/drive/MyDrive/MasterCourse/CapstonProject03/Data/Movie_details.csv")

# %%
df.head()
# Out:
#                       title  \
# 0  The Shawshank Redemption
# 1             The Godfather
# 2                     Daman
# 3            Hababam Sinifi
# 4           The Dark Knight
#
#                                          description                genres
# 0  Over the course of several years, two convicts...                 Drama
# 1  The aging patriarch of an organized crime dyna...          Crime, Drama
# 2  The film is set in 2015. Sid, is a young docto...      Adventure, Drama
# 3  Lazy, uneducated students share a very close b...         Comedy, Drama
# 4  When the menace known as the Joker wreaks havo...  Action, Crime, Drama

# %%
genres_list = df.genres.tolist()
genres = []
for genre in genres_list:
  genres.append(genre.split(", "))
genres
# Out:
# [['Drama'],
#  ['Crime', 'Drama'],
#  ['Adventure', 'Drama'],
#  ['Comedy', 'Drama'],
#  ['Action', 'Crime', 'Drama'],
#  ['Biography', 'Drama', 'History'],
#  ['Action', 'Adventure', 'Drama'],
#  ['Crime', 'Drama'],
#  ['Crime', 'Drama'],
#  ['Crime', 'Mystery', 'Thriller'],
#  ['Crime', 'Drama'],
#  ['Animation', 'Action', 'Fantasy'],
#  ['Adventure', 'Comedy', 'Drama'],
#  ['Comedy', 'Drama'],
#  ['Comedy', 'Family', 'Mystery'],
#  ['Comedy'],
#  ['Comedy'],
#  ['Action', 'Adventure', 'Drama'],
#  ['Action', 'Adventure', 'Sci-Fi'],
#  ['Drama'],
#  ['Drama', 'Romance'],
#  ['Action', 'Adventure', 'Drama'],
#  ['Adventure', 'Western'],
#  ['Crime', 'Drama', 'Mystery'],
#  ['Action', 'Crime', 'Thriller'],
#  ['Animation', 'Action', 'Fantasy'],
#  ['Biography', 'Drama'],
#  ['Adventure', 'Comedy', 'Drama'],
#  ['Comedy', 'Drama'],
#  ['Drama'],
#  ['Comedy', 'Horror', 'Mystery'],
#  ['Adventure', 'Comedy'],
#  ['Action', 'Sci-Fi'],
#  ['Drama'],
#  ['Biography', 'Crime', 'Drama'],
# ...

# %%
len(genres)
# Out:
# 9310

# %%
df = df.drop('genres', axis=1)
df['genres'] = genres
df.head()
# Out:
#                       title  \
# 0  The Shawshank Redemption
# 1             The Godfather
# 2                     Daman
# 3            Hababam Sinifi
# 4           The Dark Knight
#
#                                          description                  genres
# 0  Over the course of several years, two convicts...                 [Drama]
# 1  The aging patriarch of an organized crime dyna...          [Crime, Drama]
# 2  The film is set in 2015. Sid, is a young docto...      [Adventure, Drama]
# 3  Lazy, uneducated students share a very close b...         [Comedy, Drama]
# 4  When the menace known as the Joker wreaks havo...  [Action, Crime, Drama]

# %%
df.to_csv('/content/drive/MyDrive/MasterCourse/CapstonProject03/Data/Movies_data.csv', index=False)
